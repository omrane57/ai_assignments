# %%
import pandas as pd

# %%
# 1. Load Dataset:
# o Load the Airbnb Listings dataset using Pandas. How many rows and columns
# does the dataset have?
original_df=pd.read_csv('listings.csv')
print(original_df.shape)
# Out:
# (3818, 92)

# %%
# 2. Basic Information:
# o Display the first 5 rows of the dataset.
original_df.head(5)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
# 3. Column Names:
# o List all column names from the dataset.
original_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %%
# 4. Data Types:
# o Check the data types of all the columns.
col_info=original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
# 5. Handling Missing Values:
# o Count the total number of missing values in the dataset.
total_null_dataset=original_df.isna().sum()
print(total_null_dataset)
# Out:
# id                                    0
# listing_url                           0
# scrape_id                             0
# last_scraped                          0
# name                                  0
#                                    ...
# cancellation_policy                   0
# require_guest_profile_picture         0
# require_guest_phone_verification      0
# calculated_host_listings_count        0
# reviews_per_month                   627
# Length: 92, dtype: int64

# %%
# Drop any irrelevant columns like 'id' or 'host_id' and display the new
# dataframe.
new_df=original_df.drop(['id','host_id'],axis=1)
new_df.columns
# Out:
# Index(['listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %%
# 7. Basic Summary Statistics:
# o Show the summary statistics for all numerical columns.
new_df.describe()
# Out:
#           scrape_id  host_listings_count  host_total_listings_count  \
# count  3.818000e+03          3816.000000                3816.000000
# mean   2.016010e+13             7.157757                   7.157757
# std    0.000000e+00            28.628149                  28.628149
# min    2.016010e+13             1.000000                   1.000000
# 25%    2.016010e+13             1.000000                   1.000000
# 50%    2.016010e+13             1.000000                   1.000000
# 75%    2.016010e+13             3.000000                   3.000000
# max    2.016010e+13           502.000000                 502.000000
#
#           latitude    longitude  accommodates    bathrooms     bedrooms  \
# count  3818.000000  3818.000000   3818.000000  3802.000000  3812.000000
# mean     47.628961  -122.333103      3.349398     1.259469     1.307712
# std       0.043052     0.031745      1.977599     0.590369     0.883395
# ...

# %%
new_df.columns
# Out:
# Index(['listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %%
df
# Out:
#             id                            listing_url       scrape_id  \
# 0       241032    https://www.airbnb.com/rooms/241032  20160104002432
# 1       953595    https://www.airbnb.com/rooms/953595  20160104002432
# 2      3308979   https://www.airbnb.com/rooms/3308979  20160104002432
# 3      7421966   https://www.airbnb.com/rooms/7421966  20160104002432
# 4       278830    https://www.airbnb.com/rooms/278830  20160104002432
# ...        ...                                    ...             ...
# 3813   8101950   https://www.airbnb.com/rooms/8101950  20160104002432
# 3814   8902327   https://www.airbnb.com/rooms/8902327  20160104002432
# 3815  10267360  https://www.airbnb.com/rooms/10267360  20160104002432
# 3816   9604740   https://www.airbnb.com/rooms/9604740  20160104002432
# 3817  10208623  https://www.airbnb.com/rooms/10208623  20160104002432
#
#      last_scraped                                 name  \
# 0      2016-01-04         Stylish Queen Anne Apartment
# ...

# %%
new_dfs=original_df
# new_dfs['price']=new_dfs['price'].str.replace(r'[^0-9.]', '', regex=True)
new_dfs['price']=pd.to_numeric(new_dfs['price'])
price_grater_than_100=new_dfs[new_dfs['price']>100]
price_grater_than_100[['id','price']]
# price_grater_than_100['id','price']
# Out:
#            id  price
# 1      953595  150.0
# 2     3308979  975.0
# 4      278830  450.0
# 5     5956968  120.0
# 9     2493658  150.0
# ...       ...    ...
# 3807  4940491  109.0
# 3808  1844791  175.0
# 3809  6120046  120.0
# 3810   262764  154.0
# 3813  8101950  359.0
#
# [1858 rows x 2 columns]

# %%
sorted_data_based_on_price=new_dfs.sort_values('price',ascending=False)
sorted_data_based_on_price[['price','id']]
# Out:
#        price        id
# 3122  1000.0   4825073
# 1208   999.0   3345341
# 2      975.0   3308979
# 3443   950.0   2720963
# 1279   899.0   4464824
# ...      ...       ...
# 1923    25.0   8566475
# 79      25.0   7011773
# 2251    25.0   7411863
# 3580    22.0  10248139
# 53      20.0  10310373
#
# [3818 rows x 2 columns]

# %%
sorted_data_based_on_price.rename(columns={"price":"listing_price"},inplace=True)
sorted_data_based_on_price[["listing_price","id"]]
# Out:
#       listing_price        id
# 3122         1000.0   4825073
# 1208          999.0   3345341
# 2             975.0   3308979
# 3443          950.0   2720963
# 1279          899.0   4464824
# ...             ...       ...
# 1923           25.0   8566475
# 79             25.0   7011773
# 2251           25.0   7411863
# 3580           22.0  10248139
# 53             20.0  10310373
#
# [3818 rows x 2 columns]

# %%
unique_room_type_counts = original_df['room_type'].value_counts()

# Show the result
print(unique_room_type_counts)
# Out:
# room_type
# Entire home/apt    2541
# Private room       1160
# Shared room         117
# Name: count, dtype: int64

# %%
original_df[['neighbourhood', 'room_type',]]
# Out:
#      neighbourhood        room_type
# 0       Queen Anne  Entire home/apt
# 1       Queen Anne  Entire home/apt
# 2       Queen Anne  Entire home/apt
# 3       Queen Anne  Entire home/apt
# 4       Queen Anne  Entire home/apt
# ...            ...              ...
# 3813       Fremont  Entire home/apt
# 3814   Portage Bay  Entire home/apt
# 3815           NaN  Entire home/apt
# 3816           NaN  Entire home/apt
# 3817    Queen Anne  Entire home/apt
#
# [3818 rows x 2 columns]

# %%
# Group by 'neighbourhood' and calculate the mean of 'listing_price'
mean_price_by_neighbourhood = original_df.groupby('neighbourhood')['price'].mean()

# Display the result
print(mean_price_by_neighbourhood)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[233], line 2
#       1 # Group by 'neighbourhood' and calculate the mean of 'listing_price'
# ----> 2 mean_price_by_neighbourhood = original_df.groupby('neighbourhood')['listing_price'].mean()
#       4 # Display the result
#       5 print(mean_price_by_neighbourhood)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# ...
